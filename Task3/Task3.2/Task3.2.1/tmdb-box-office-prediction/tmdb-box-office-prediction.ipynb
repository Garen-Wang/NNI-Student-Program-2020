# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('~/data/task3_2/tmdb-box-office-prediction/train.csv')
test = pd.read_csv('~/data/task3_2/tmdb-box-office-prediction/test.csv')
train.rename(columns={'belongs_to_collection': 'belongs-to-collection', 'imdb_id': 'imdb-id', 'original_language': 'original-language', 'original_title': 'original-title', 'poster_path': 'poster-path', 'production_companies': 'production-companies', 'production_countries': 'production-countries', 'release_date': 'release-date', 'spoken_languages': 'spoken-languages'}, inplace=True)
test.rename(columns={'belongs_to_collection': 'belongs-to-collection', 'imdb_id': 'imdb-id', 'original_language': 'original-language', 'original_title': 'original-title', 'poster_path': 'poster-path', 'production_companies': 'production-companies', 'production_countries': 'production-countries', 'release_date': 'release-date', 'spoken_languages': 'spoken-languages'}, inplace=True)

# %%
train.head()
# Out:
#    id                              belongs-to-collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb-id original-language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original-title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release-date runtime                                   spoken-languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
train.isnull().sum()
# Out:
# id                          0
# belongs-to-collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb-id                     0
# original-language           0
# original-title              0
# overview                    8
# popularity                  0
# poster-path                 1
# production-companies      156
# production-countries       55
# release-date                0
# runtime                     2
# spoken-languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                          0
# belongs-to-collection    3521
# budget                      0
# genres                     16
# homepage                 2978
# imdb-id                     0
# original-language           0
# original-title              0
# overview                   14
# popularity                  0
# poster-path                 1
# production-companies      258
# production-countries      102
# release-date                1
# runtime                     4
# spoken-languages           42
# status                      2
# tagline                   863
# title                       3
# Keywords                  393
# cast                       13
# crew                       22
# dtype: int64

# %%
train.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
plt.hist(np.log1p(train['revenue']))
plt.show()

# %%
train['log-revenue'] = np.log1p(train['revenue']) # and we just predict log-revenue, and take exp

# %%
train['has-collection'] = train['belongs-to-collection'].map(lambda x: 1 if pd.notna(x) else 0)
test['has-collection'] = test['belongs-to-collection'].map(lambda x: 1 if pd.notna(x) else 0)

# %%
median = train.loc[train['budget'] > 0, 'budget'].median()
train['budget'] = train['budget'].map(lambda x: x if x > 0 else median)
test['budget'] = test['budget'].map(lambda x: x if x > 0 else median)

# %%
plt.hist(np.log1p(train['budget']))
plt.show()

# %%
train['log-budget'] = np.log1p(train['budget'])
test['log-budget'] = np.log1p(test['budget'])

# %%
train['genres'] = train['genres'].fillna('[]')
test['genres'] = test['genres'].fillna('[]')

train['genres-count'] = train['genres'].map(lambda x: len(eval(x)))
test['genres-count'] = test['genres'].map(lambda x: len(eval(x)))

# %%
from wordcloud import WordCloud
genres_dict = {}
for val in train['genres']:
    for v in eval(val):
        if v['name'] not in genres_dict.keys():
            genres_dict[v['name']] = 1
        else:
            genres_dict[v['name']] += 1
wc = WordCloud(background_color='white', width=1000, height=1000).generate_from_frequencies(genres_dict)
plt.figure(figsize=(10, 10))
plt.imshow(wc)
plt.axis('off')
plt.title('genres wordcloud')
plt.show()

# %%
sorted(genres_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Drama', 1531),
#  ('Comedy', 1028),
#  ('Thriller', 789),
#  ('Action', 741),
#  ('Romance', 571),
#  ('Crime', 469),
#  ('Adventure', 439),
#  ('Horror', 301),
#  ('Science Fiction', 290),
#  ('Family', 260),
#  ('Fantasy', 232),
#  ('Mystery', 225),
#  ('Animation', 141),
#  ('History', 132),
#  ('Music', 100),
#  ('War', 100),
#  ('Documentary', 87),
#  ('Western', 43),
#  ('Foreign', 31),
#  ('TV Movie', 1)]

# %%
from ast import literal_eval
def inJson(val, name):
    for x in literal_eval(val):
        if name == x['name']:
            return 1
    return 0

# %%
top_genres_dict = {}
for val in train[['genres', 'revenue']].values:
    x = literal_eval(val[0])
    temp = min(1, len(x))
    for i in range(temp):
        name = x[i]['name']
        if name not in top_genres_dict.keys():
            top_genres_dict[name] = [val[1], 1]
        else:
            top_genres_dict[name][0] += val[1]
            top_genres_dict[name][1] += 1

for x in top_genres_dict.keys():
    top_genres_dict[x] = top_genres_dict[x][0] / top_genres_dict[x][1]

# %%
sorted(top_genres_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Adventure', 187715537.32085562),
#  ('Science Fiction', 163833801.36585367),
#  ('Family', 157347482.6111111),
#  ('Animation', 148089684.90789473),
#  ('Action', 93596599.80576923),
#  ('Fantasy', 82345105.41176471),
#  ('Western', 64905713.538461536),
#  ('Thriller', 56574423.54310345),
#  ('Romance', 51648567.82089552),
#  ('Horror', 49586852.62352941),
#  ('Comedy', 47754836.36092715),
#  ('Mystery', 47674838.90909091),
#  ('History', 44237822.875),
#  ('TV Movie', 42000000.0),
#  ('Crime', 40820052.02040816),
#  ('Drama', 37298750.1133758),
#  ('Music', 33890384.55),
#  ('War', 24388514.85),
#  ('Documentary', 3538249.971830986),
#  ('Foreign', 140650.0)]

# %%
train['genres-rank'] = train['genres'].map(lambda x: list(top_genres_dict.keys()).index(literal_eval(x)[0]['name']) + 1 if x != '[]' else 0)
test['genres-rank'] = test['genres'].map(lambda x: list(top_genres_dict.keys()).index(literal_eval(x)[0]['name']) + 1 if x != '[]' else 0)

# %%
train['has-homepage'] = train['homepage'].map(lambda x: 1 if pd.notna(x) else 0)
test['has-homepage'] = test['homepage'].map(lambda x: 1 if pd.notna(x) else 0)

# %%
sns.catplot(x='original-language', y='revenue', data=train)

# %%
train['originally-english'] = train['original-language'].map(lambda x: 1 if x == 'en' else 0)
test['originally-english'] = test['original-language'].map(lambda x: 1 if x == 'en' else 0)

# %%
train.drop(['imdb-id', 'original-title', 'poster-path'], axis=1, inplace=True)
test.drop(['imdb-id', 'original-title', 'poster-path'], axis=1, inplace=True)

# %%
train['overview'] = train['overview'].fillna('')
test['overview'] = test['overview'].fillna('')
train['overview-length'] = train['overview'].map(len)
test['overview-length'] = test['overview'].map(len)

# %%
plt.hist(train['overview-length'])
# Out:
# (array([135., 783., 695., 701., 382., 126.,  83.,  42.,  30.,  23.]),
#  array([   0. ,  100.7,  201.4,  302.1,  402.8,  503.5,  604.2,  704.9,
#          805.6,  906.3, 1007. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log1p(train['popularity']))
# Out:
# (array([180., 290., 368., 999., 986., 140.,  23.,   6.,   3.,   5.]),
#  array([9.99999500e-07, 5.68812620e-01, 1.13762424e+00, 1.70643586e+00,
#         2.27524748e+00, 2.84405910e+00, 3.41287072e+00, 3.98168234e+00,
#         4.55049396e+00, 5.11930558e+00, 5.68811720e+00]),
#  <BarContainer object of 10 artists>)

# %%
train['log-popularity'] = np.log1p(train['popularity'])
test['log-popularity'] = np.log1p(test['popularity'])

# %%
train['production-companies'] = train['production-companies'].fillna('[]')
test['production-companies'] = test['production-companies'].fillna('[]')
train['companies-count'] = train['production-companies'].map(lambda x: len(eval(x)))
test['companies-count'] = test['production-companies'].map(lambda x: len(eval(x)))

# %%
from wordcloud import WordCloud
companies_dict = {}
for val in train['production-companies']:
    for v in eval(val):
        if v['name'] not in companies_dict.keys():
            companies_dict[v['name']] = 1
        else:
            companies_dict[v['name']] += 1
wc = WordCloud(background_color='white', width=1000, height=1000).generate_from_frequencies(companies_dict)
plt.figure(figsize=(10, 10))
plt.imshow(wc)
plt.axis('off')
plt.title('companies wordcloud')
plt.show()

# %%
top_companies_dict = {}
for val in train[['production-companies', 'revenue']].values:
    temp = min(3, len(literal_eval(val[0])))
    for i in range(temp):
        name = literal_eval(val[0])[i]['name']
        if name not in top_companies_dict.keys():
            top_companies_dict[name] = [val[1], 1]
        else:
            top_companies_dict[name][0] += val[1]
            top_companies_dict[name][1] += 1
for company in top_companies_dict.keys():
    top_companies_dict[company][0] = top_companies_dict[company][0] / top_companies_dict[company][1]
    top_companies_dict[company] = top_companies_dict[company][0]

# %%
top_companies_dict = dict(sorted(top_companies_dict.items(), key=lambda x: x[1], reverse=True))

# %%
train['companies-rank'] = train['production-companies'].map(lambda x: list(top_companies_dict.keys()).index(literal_eval(x)[0]['name']) + 1 if x != '[]' else 0)
test['companies-rank'] = test['production-companies'].map(lambda x: list(top_companies_dict.keys()).index(literal_eval(x)[0]['name']) + 1 if x != '[]' and literal_eval(x)[0]['name'] in top_companies_dict.keys() else 0)

# %%
top_companies = list(top_companies_dict)[:50]
train['top-companies-count'] = train['production-companies'].map(lambda x: inJson(x, top_companies))
test['top-companies-count'] = test['production-companies'].map(lambda x: inJson(x, top_companies))

# %%
train['production-countries'] = train['production-countries'].fillna('[]')
test['production-countries'] = test['production-countries'].fillna('[]')

train['countries-count'] = train['production-countries'].map(lambda x: len(literal_eval(x)))
test['countries-count'] = test['production-countries'].map(lambda x: len(literal_eval(x)))

# %%
from wordcloud import WordCloud
countries_dict = {}
for val in train['production-countries']:
    for v in eval(val):
        if v['iso_3166_1'] not in countries_dict.keys():
            countries_dict[v['iso_3166_1']] = 1
        else:
            countries_dict[v['iso_3166_1']] += 1
wc = WordCloud(background_color='white', width=1000, height=1000).generate_from_frequencies(countries_dict)
plt.figure(figsize=(10, 10))
plt.imshow(wc)
plt.axis('off')
plt.title('countries wordcloud')
plt.show()

# %%
top_countries_dict = {}
for val in train[['production-countries', 'revenue']].values:
    for x in literal_eval(val[0]):
        if x['iso_3166_1'] not in top_countries_dict.keys():
            top_countries_dict[x['iso_3166_1']] = [val[1], 1]
        else:
            top_countries_dict[x['iso_3166_1']][0] += val[1]
            top_countries_dict[x['iso_3166_1']][1] += 1
for top_country in top_countries_dict.keys():
    top_countries_dict[top_country] = top_countries_dict[top_country][0]
top_countries_dict = dict(sorted(top_countries_dict.items(), key=lambda x: x[1], reverse=True))

# %%
top_countries_dict
# Out:
# {'US': 187048227401,
#  'GB': 27639015794,
#  'DE': 12719359779,
#  'CA': 9252955680,
#  'FR': 8249447774,
#  'NZ': 5245506886,
#  'AU': 4041396552,
#  'JP': 3294365863,
#  'CN': 3160045628,
#  'HK': 2800993770,
#  'IT': 2642404428,
#  'CZ': 2286171511,
#  'IN': 1902638398,
#  'ES': 1654397485,
#  'AE': 963490546,
#  'RU': 735730439,
#  'ZA': 662193142,
#  'MX': 645237085,
#  'MT': 601276370,
#  'IE': 562187384,
#  'BE': 549931644,
#  'TW': 539971962,
#  'PL': 452128851,
#  'SI': 419651413,
#  'HU': 415618897,
#  'IS': 355855544,
#  'KR': 296455208,
#  'BG': 207155728,
#  'AT': 199873861,
#  'LU': 194419483,
#  'MA': 190719111,
#  'TR': 183235845,
#  'RO': 178521836,
#  'UY': 163794509,
#  'PY': 163794509,
#  'SE': 160508880,
#  'DK': 149340359,
#  'BS': 149252232,
#  'SG': 131052868,
#  'CH': 99958441,
#  'KH': 86286687,
#  'NL': 83390272,
#  'AR': 67192469,
#  'GR': 57559512,
#  'CL': 49051151,
#  'BR': 35910916,
#  'TN': 30749038,
#  'RS': 29657949,
#  'HR': 28400000,
#  'FI': 27331973,
#  'IL': 20377183,
#  'PK': 19574006,
#  'PE': 16756372,
#  'PT': 15530077,
#  'NO': 10651591,
#  'UA': 10212668,
#  'CR': 7191399,
#  'QA': 5965535,
#  'NA': 4192440,
#  'IR': 3560926,
#  'MN': 3162153,
#  'BF': 2691899,
#  'GH': 2691899,
#  'ID': 2649042,
#  'SA': 1347747,
#  'JO': 1347747,
#  'CS': 1072602,
#  'DZ': 921548,
#  'PR': 837000,
#  'BA': 138730,
#  'ET': 49667,
#  'PH': 34969,
#  'MR': 7406,
#  'CY': 135}

# %%
def inCountry(x):
    for val in literal_eval(x):
        if val['iso_3166_1'] == 'US':
            return 1
    return 0

train['usa-produced'] = train['production-countries'].map(lambda x: inCountry(x))
test['usa-produced'] = test['production-countries'].map(lambda x: inCountry(x))

# %%
test.loc[test['release-date'].isnull(), 'release-date'] = '5/1/00'

# %%
train['release-date'] = train['release-date'].map(lambda x: pd.to_datetime(x))
train['year'] = train['release-date'].map(lambda x: x.year)
train['month'] = train['release-date'].map(lambda x: x.month)
train['day'] = train['release-date'].map(lambda x: x.day)
train['dayofweek'] = train['release-date'].map(lambda x: x.dayofweek + 1)
train['weekofyear'] = train['release-date'].map(lambda x: x.weekofyear)
train['quarter'] = train['release-date'].map(lambda x: x.quarter)
test['release-date'] = test['release-date'].map(lambda x: pd.to_datetime(x))
test['year'] = test['release-date'].map(lambda x: x.year)
test['month'] = test['release-date'].map(lambda x: x.month)
test['day'] = test['release-date'].map(lambda x: x.day)
test['dayofweek'] = test['release-date'].map(lambda x: x.dayofweek + 1)
test['weekofyear'] = test['release-date'].map(lambda x: x.weekofyear)
test['quarter'] = test['release-date'].map(lambda x: x.quarter)

train['year'] = train['year'].map(lambda x: x - 100 if x >= 2018 else x)
test['year'] = test['year'].map(lambda x: x - 100 if x >= 2018 else x)

# %%
train.drop(train['runtime'].argmax(), inplace=True)

# %%
train['runtime'].interpolate(method='values', inplace=True)
test['runtime'].interpolate(method='values', inplace=True)

# %%
plt.hist(train['runtime'])
# Out:
# (array([1.300e+01, 2.000e+00, 2.500e+01, 1.138e+03, 1.258e+03, 4.220e+02,
#         1.040e+02, 2.900e+01, 7.000e+00, 1.000e+00]),
#  array([  0. ,  24.8,  49.6,  74.4,  99.2, 124. , 148.8, 173.6, 198.4,
#         223.2, 248. ]),
#  <BarContainer object of 10 artists>)

# %%
train['spoken-languages'] = train['spoken-languages'].fillna('[]')
test['spoken-languages'] = test['spoken-languages'].fillna('[]')

train['spoken-languages-count'] = train['spoken-languages'].map(lambda x: len(literal_eval(x)))
test['spoken-languages-count'] = test['spoken-languages'].map(lambda x: len(literal_eval(x)))

# %%
train['spoken-english'] = train['spoken-languages'].map(lambda x: inJson(x, 'English'))
test['spoken-english'] = test['spoken-languages'].map(lambda x: inJson(x, 'English'))

# %%
train.drop('status', axis=1, inplace=True)
test.drop('status', axis=1, inplace=True)

# %%
train['has-tagline'] = train['tagline'].map(lambda x: 1 if pd.notnull(x) else 0)
test['has-tagline'] = test['tagline'].map(lambda x: 1 if pd.notnull(x) else 0)

train['tagline'] = train['tagline'].fillna('')
test['tagline'] = test['tagline'].fillna('')

# %%
train['title'] = train['title'].fillna('')
test['title'] = test['title'].fillna('')
train['title-length'] = train['title'].map(lambda x: len(x))
test['title-length'] = test['title'].map(lambda x: len(x))

# %%
train['has-keywords'] = train['Keywords'].map(lambda x: 1 if pd.notnull(x) else 0)
test['has-keywords'] = test['Keywords'].map(lambda x: 1 if pd.notnull(x) else 0)
train['Keywords'] = train['Keywords'].fillna('')
test['Keywords'] = test['Keywords'].fillna('')

# %%
train['cast'] = train['cast'].fillna('[]')
test['cast'] = test['cast'].fillna('[]')
train['cast-count'] = train['cast'].map(lambda x: len(literal_eval(x)))
test['cast-count'] = test['cast'].map(lambda x: len(literal_eval(x)))
train['log-cast-count'] = np.log1p(train['cast-count'])
test['log-cast-count'] = np.log1p(test['cast-count'])

# %%
plt.hist(np.log1p(train['cast-count']))
# Out:
# (array([  26.,   16.,   31.,  185.,  577., 1075.,  684.,  277.,  101.,
#           27.]),
#  array([0.        , 0.50562458, 1.01124916, 1.51687374, 2.02249832,
#         2.5281229 , 3.03374748, 3.53937206, 4.04499664, 4.55062122,
#         5.05624581]),
#  <BarContainer object of 10 artists>)

# %%
actors_dict = {}
for element in train[['cast', 'revenue']].values:
    temp = min(5, len(literal_eval(element[0])))
    for i in range(temp):
        name = literal_eval(element[0])[i]['name']
        if name not in actors_dict:
            actors_dict[name] = [element[1], 1]
        else:
            actors_dict[name][0] += element[1]
            actors_dict[name][1] += 1
actors_dict = {k: v for k, v in actors_dict.items() if v[1] >= 5}
for actor in actors_dict:
    actors_dict[actor] = actors_dict[actor][0] / actors_dict[actor][1]

# %%
sorted(actors_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Tyrese Gibson', 643678711.6),
#  ('Ian McKellen', 585298204.875),
#  ('Emma Watson', 579056739.0),
#  ('Chris Hemsworth', 521686952.1666667),
#  ('Chris Evans', 465336451.6666667),
#  ('Orlando Bloom', 450570885.375),
#  ('Megan Fox', 411813835.0),
#  ('Shia LaBeouf', 409059041.3),
#  ('Vin Diesel', 403237367.3),
#  ('Josh Duhamel', 388336592.1111111),
#  ('Hayden Christensen', 359219191.6),
#  ('Mark Ruffalo', 348523404.3),
#  ('Scarlett Johansson', 314240111.64285713),
#  ('Anne Hathaway', 311294146.71428573),
#  ('Sharlto Copley', 307427688.0),
#  ('Frances McDormand', 306671857.6666667),
#  ('Simon Pegg', 304443721.4285714),
#  ('Elijah Wood', 297430093.5),
#  ('Ken Jeong', 295094661.5),
#  ('Queen Latifah', 292738983.125),
#  ('Paul Walker', 292241853.125),
#  ('Johnny Depp', 288573267.3125),
#  ('Robert Pattinson', 285498366.4),
#  ('Laura Dern', 284156771.2),
#  ('Kristen Stewart', 282323823.6),
#  ('Daniel Craig', 277392845.45454544),
#  ('Ian McShane', 275549764.4),
#  ('Jack Black', 274264298.4),
#  ('Cate Blanchett', 260901734.85714287),
#  ('Bonnie Hunt', 259354614.8),
#  ('Michelle Rodriguez', 257280266.3),
#  ('Zoe Saldana', 249774141.625),
#  ('Natalie Portman', 249019115.33333334),
#  ('Seann William Scott', 248720317.16666666),
#  ('Dwayne Johnson', 247468261.16666666),
#  ('Ryan Reynolds', 247443278.57142857),
#  ('Glenn Close', 241202510.6),
#  ('Idris Elba', 239426012.0),
#  ('Sean Bean', 237483038.75),
#  ('Bradley Cooper', 237433014.7857143),
#  ('Robert Downey Jr.', 231335189.25),
#  ('Keira Knightley', 230117719.375),
#  ('Jeremy Renner', 229130676.42857143),
#  ('Chris Tucker', 228374199.4),
#  ('John Leguizamo', 226924887.25),
#  ('Will Smith', 224687407.5),
#  ('Kristen Wiig', 224395611.2857143),
#  ('Mia Wasikowska', 219997247.0),
#  ('Hugh Jackman', 219533562.53846154),
#  ('Tom Cruise', 217922140.0),
#  ('Judi Dench', 215939348.57142857),
#  ('John Malkovich', 215325974.6),
#  ('Famke Janssen', 213326047.66666666),
#  ('Sam Neill', 213110568.42857143),
#  ('Harrison Ford', 211452486.14285713),
#  ('Kevin Costner', 211301099.91666666),
#  ('Kevin James', 207453307.5),
#  ('Gary Oldman', 205551068.73333332),
#  ('Alan Rickman', 203671605.0),
#  ('Heath Ledger', 199611921.0),
#  ('Angelina Jolie', 198312318.2857143),
#  ('Leslie Mann', 197063527.5),
#  ('Max von Sydow', 196529624.33333334),
#  ('Helena Bonham Carter', 195491456.42857143),
#  ('Jeffrey Wright', 194490213.83333334),
#  ('Ralph Fiennes', 190447827.0),
#  ('Geoffrey Rush', 190363702.36363637),
#  ('Samuel L. Jackson', 186275356.04761904),
#  ('Kevin Kline', 183482701.0),
#  ('Stanley Tucci', 179291456.75),
#  ('Karen Allen', 176814404.8),
#  ('Pierce Brosnan', 174790446.7),
#  ('Ed Harris', 173785261.17647058),
#  ('Anthony Hopkins', 173684222.9090909),
#  ('Billy Burke', 173229208.6),
#  ('Jamie Foxx', 172564690.33333334),
#  ('Jack Nicholson', 172043640.4),
#  ('Jim Carrey', 171894169.33333334),
#  ('Pen√©lope Cruz', 171742008.2222222),
#  ('Hank Azaria', 169825362.7142857),
#  ('Christopher Lloyd', 169454676.8),
#  ('Talia Shire', 168825945.4),
#  ('Patrick Stewart', 167633661.7777778),
#  ('Rosamund Pike', 167056864.7142857),
#  ('Diane Kruger', 166501722.83333334),
#  ('Mark Wahlberg', 165462924.1111111),
#  ('Tom Hanks', 164777059.93333334),
#  ('George Clooney', 164558061.6470588),
#  ('James Earl Jones', 164453873.375),
#  ('Gerard Butler', 164121148.66666666),
#  ('Viggo Mortensen', 163290282.25),
#  ('Michael Caine', 161811649.29411766),
#  ('Mila Kunis', 161778922.57142857),
#  ('Halle Berry', 161077946.07692307),
#  ('Adam Sandler', 158704020.54545453),
#  ('Tony Goldwyn', 157990382.42857143),
#  ('Zooey Deschanel', 157690044.83333334),
#  ('Arnold Schwarzenegger', 156729287.5),
#  ('Diane Keaton', 156055755.0),
#  ('Logan Lerman', 155346302.83333334),
#  ('Vera Farmiga', 155236668.375),
#  ('Ewan McGregor', 155173976.4),
#  ('Zach Galifianakis', 154978534.0),
#  ('Seth Rogen', 154976989.2857143),
#  ('Charlie Tahan', 154617945.0),
#  ('Michael Pe√±a', 154555905.66666666),
#  ('Brad Pitt', 153725280.69230768),
#  ('Jonah Hill', 150723199.57142857),
#  ('Owen Wilson', 149759160.63157895),
#  ('Sandra Bullock', 148680641.0),
#  ('Steve Carell', 148445865.375),
#  ('Paul Bettany', 147233143.5),
#  ('Olga Kurylenko', 146944047.4),
#  ('Josh Hutcherson', 146781715.625),
#  ('Christian Bale', 144469782.2352941),
#  ('Giovanni Ribisi', 144408567.5),
#  ('Jesse Eisenberg', 144128181.2),
#  ('David Wenham', 144115309.4),
#  ('Stellan Skarsg√•rd', 143801732.5),
#  ('Cameron Diaz', 143628893.45454547),
#  ('Tom Hardy', 143074211.75),
#  ('Diego Luna', 142776023.8),
#  ('Amy Adams', 142368425.33333334),
#  ('Amanda Seyfried', 142291832.4),
#  ('Jason Bateman', 142083426.46666667),
#  ('Demi Moore', 140813884.5),
#  ('Jeremy Irons', 140199609.66666666),
#  ('Matt Damon', 139716333.6470588),
#  ('Jodie Foster', 139678035.8),
#  ('Sylvester Stallone', 139365148.8888889),
#  ('Michael J. Fox', 138640225.875),
#  ('Jackie Chan', 138345819.7),
#  ('Richard Harris', 138034730.0),
#  ('Nicholas Hoult', 137924453.0),
#  ('Garrett Hedlund', 136962057.83333334),
#  ('Domhnall Gleeson', 136904740.33333334),
#  ('Julia Roberts', 136504295.14285713),
#  ('Milla Jovovich', 135906775.27272728),
#  ('Hugh Grant', 134996797.44444445),
#  ('Richard Dreyfuss', 133739216.83333333),
#  ('Abigail Breslin', 132996291.85714285),
#  ('Alfre Woodard', 132280788.8),
#  ('Leonardo DiCaprio', 130636801.875),
#  ('Jon Voight', 130101294.27272727),
#  ('Kevin Spacey', 129592513.0909091),
#  ('Aaron Eckhart', 129346153.92307693),
#  ('Regina King', 126295096.4),
#  ('Holly Hunter', 125619245.14285715),
#  ('Al Pacino', 125531523.36363636),
#  ('Charles S. Dutton', 124262150.4),
#  ('Jim Caviezel', 123237296.71428572),
#  ('Channing Tatum', 123223724.71428572),
#  ('Matthew Broderick', 123006306.45454545),
#  ('Michelle Monaghan', 122995931.33333333),
#  ('Richard Jenkins', 122963906.25),
#  ('Mel Gibson', 122795406.5),
#  ('Carl Weathers', 121734856.4),
#  ('Robin Williams', 121663071.07142857),
#  ('Tony Shalhoub', 121363404.5),
#  ('Liam Neeson', 121275558.21052632),
#  ('Anna Faris', 120903697.16666667),
#  ('Andy Garc√≠a', 120880541.66666667),
#  ('Michael Douglas', 120587045.41666667),
#  ('Diane Lane', 120577946.81818181),
#  ('Martin Lawrence', 119225262.6),
#  ('Colin Hanks', 116889880.8),
#  ('Sean Connery', 116657779.53846154),
#  ('Laura Linney', 116655916.5),
#  ('Lisa Kudrow', 116000087.85714285),
#  ('Robert Redford', 115984233.58333333),
#  ('Heather Graham', 115804482.33333333),
#  ('Eddie Murphy', 115401013.86666666),
#  ('Reese Witherspoon', 114141714.125),
#  ('Ellen Burstyn', 112971096.2),
#  ('Ben Stiller', 111147817.3),
#  ('Denise Richards', 110762786.0),
#  ('Russell Crowe', 110124512.21428572),
#  ('Thomas Haden Church', 109804469.5),
#  ('Anne Archer', 109771099.6),
#  ('Brittany Murphy', 108907259.8),
#  ('Nathan Lane', 108886239.2),
#  ('Catherine Zeta-Jones', 108561085.875),
#  ('Goran Visnjic', 107840572.0),
#  ('Delroy Lindo', 107528451.5),
#  ('Woody Harrelson', 107512806.85714285),
#  ('John C. Reilly', 107270508.63636364),
#  ('Dianne Wiest', 107158714.2),
#  ('Val Kilmer', 107086626.0),
#  ('Vince Vaughn', 107013702.0),
#  ('Michael Keaton', 106710928.57142857),
#  ('Kate Beckinsale', 106379764.0),
#  ('John Travolta', 105983477.41666667),
#  ('Hugo Weaving', 105774830.2),
#  ('Adrien Brody', 105757922.0),
#  ('Patrick Swayze', 105506997.0),
#  ('Nicolas Cage', 104670875.78947368),
#  ('Chris Cooper', 104567299.71428572),
#  ('Anna Kendrick', 104303556.375),
#  ('Brendan Gleeson', 104070343.92307693),
#  ('William Shatner', 103840000.0),
#  ('Teresa Palmer', 103630073.33333333),
#  ('Rachel McAdams', 102107551.6),
#  ('Alec Baldwin', 101966515.4),
#  ('Carla Gugino', 100310604.5),
#  ('Nicole Kidman', 100151152.78571428),
#  ('Noomi Rapace', 99468867.8),
#  ('Christian Slater', 98875313.57142857),
#  ('Jonathan Pryce', 98685426.2),
#  ('H√©ctor Elizondo', 98096928.5),
#  ('Elizabeth Banks', 97851228.54545455),
#  ('Sarah Jessica Parker', 97527295.4),
#  ('Steve Buscemi', 97483410.4),
#  ('Claire Danes', 96757894.4),
#  ('Richard Crenna', 96476223.0),
#  ('Alan Arkin', 96155167.0),
#  ('Helen Hunt', 96071659.4),
#  ('Sam Elliott', 95355041.66666667),
#  ('Paul Rudd', 94776503.71428572),
#  ('Jessica Alba', 94493220.66666667),
#  ('Michelle Pfeiffer', 93392235.85714285),
#  ('Julia Stiles', 93293245.0),
#  ('Colin Farrell', 93024423.5),
#  ('Jessica Biel', 92614066.6),
#  ('Patrick Dempsey', 92540268.14285715),
#  ('Naomi Watts', 92100761.16666667),
#  ('Marisa Tomei', 91983306.7),
#  ('Antonio Banderas', 91870876.91666667),
#  ('Katherine Heigl', 91684890.625),
#  ("Chris O'Donnell", 91478925.16666667),
#  ('Sharon Stone', 91196398.0),
#  ('Billy Crystal', 91076667.4),
#  ('Danny DeVito', 90667933.9090909),
#  ('Sam Worthington', 90584334.42857143),
#  ('Jake Gyllenhaal', 90330826.625),
#  ('Jamie Bell', 90162897.18181819),
#  ('James McAvoy', 90040078.5),
#  ('Lea Thompson', 89776492.55555555),
#  ('Jessica Chastain', 89721741.0909091),
#  ('Jeff Daniels', 89704160.5),
#  ('Jude Law', 89616832.875),
#  ('Annette Bening', 89515317.375),
#  ('Willem Dafoe', 88789100.23076923),
#  ('Richard Gere', 88478741.46153846),
#  ('Michael Shannon', 88127136.875),
#  ('Christopher Walken', 87947169.75),
#  ('Ashton Kutcher', 87830765.16666667),
#  ('Cynthia Nixon', 87592626.4),
#  ('Cliff Curtis', 87399933.375),
#  ('Jeff Bridges', 87198338.46153846),
#  ('Jennifer Connelly', 86821687.25),
#  ('William H. Macy', 86757752.33333333),
#  ('Whoopi Goldberg', 85535814.55555555),
#  ('Katie Holmes', 85515495.66666667),
#  ('Emma Stone', 85247451.16666667),
#  ('Steve Zahn', 85242569.9090909),
#  ('Rachel Weisz', 84865605.21428572),
#  ('James Cromwell', 84834897.8),
#  ('Paul Newman', 84341849.125),
#  ('James Marsden', 84023315.6),
#  ('Jason Statham', 83890250.64705883),
#  ('Denzel Washington', 83877313.3),
#  ('James Woods', 83499637.8888889),
#  ('Jennifer Garner', 83374744.66666667),
#  ('David Morse', 83220906.16666667),
#  ('Kate Bosworth', 83187445.16666667),
#  ('Bill Paxton', 83071358.0),
#  ('Meg Ryan', 82918351.4),
#  ('Djimon Hounsou', 81561324.0),
#  ('Edward Norton', 81246868.1),
#  ('Ben Affleck', 81054165.0),
#  ('Roy Scheider', 80845905.71428572),
#  ('Ian Holm', 80677135.0),
#  ('Melissa Leo', 80340925.0),
#  ('Kevin Bacon', 79995148.26666667),
#  ('Sigourney Weaver', 79560843.13333334),
#  ('Danny Huston', 79174020.5),
#  ('Josh Brolin', 78615526.5),
#  ('Kyra Sedgwick', 78608058.0),
#  ('Morgan Freeman', 77861274.95),
#  ('Christopher Mintz-Plasse', 77407242.0),
#  ('Anthony Edwards', 77053367.16666667),
#  ('Greg Kinnear', 76444048.2),
#  ('Amanda Peet', 76432352.6),
#  ('Mary Steenburgen', 76191690.0),
#  ('John Goodman', 76177625.4),
#  ('Alfred Molina', 75738625.8),
#  ('Julie Andrews', 75729062.42857143),
#  ('Brian Cox', 75672988.57142857),
#  ('Gene Hackman', 75631409.0),
#  ('Rick Moranis', 75575744.33333333),
#  ('Lauren Graham', 74585061.2),
#  ('Burt Reynolds', 73789224.14285715),
#  ('Benjamin Bratt', 73494701.33333333),
#  ('Kirsten Dunst', 73487967.83333333),
#  ('Don Cheadle', 73180538.0),
#  ('Kris Kristofferson', 73110344.25),
#  ('Olivia Wilde', 72952852.1),
#  ('Tom Wilkinson', 72348753.72727273),
#  ('Robert Duvall', 72301551.9375),
#  ('Charlize Theron', 71909852.16666667),
#  ('Cedric the Entertainer', 70999739.0),
#  ('Stacy Keach', 70546480.0),
#  ('Joaquin Phoenix', 70504740.27272727),
#  ('Juliette Lewis', 70403420.4),
#  ('Uma Thurman', 70129055.22222222),
#  ('Drew Barrymore', 70109495.27272727),
#  ('Tobey Maguire', 70107759.4),
#  ('Scott Glenn', 69809008.0),
#  ('Liev Schreiber', 69806524.25),
#  ('Jennifer Aniston', 69661819.16666667),
#  ('Bradley Whitford', 69485281.83333333),
#  ('James Caan', 69133512.0),
#  ('Sally Field', 68376769.6),
#  ('Cuba Gooding Jr.', 67924175.2),
#  ('Benicio del Toro', 67760556.57142857),
#  ('Maria Bello', 67585415.0),
#  ('Ren√©e Zellweger', 67563794.1111111),
#  ('Bruce Willis', 67428631.8),
#  ('Steve Martin', 66891245.28571428),
#  ('Ryan Gosling', 66822346.583333336),
#  ('Jim Broadbent', 66647762.88888889),
#  ('Marlon Brando', 66427440.75),
#  ('Michael Biehn', 66136012.2),
#  ('Terence Stamp', 65990424.75),
#  ('Catherine Keener', 65841008.222222224),
#  ('Alan Alda', 65832211.0),
#  ('Anthony Anderson', 65656233.8),
#  ('Oliver Platt', 65512430.88888889),
#  ('Ray Liotta', 65362281.692307696),
#  ('Jon Hamm', 65320053.14285714),
#  ('John Turturro', 65129921.666666664),
#  ('Michael Sheen', 65036834.0),
#  ('Michael Fassbender', 64880662.0),
#  ('Cary Elwes', 64846204.88888889),
#  ('Lindsay Lohan', 64742654.28571428),
#  ('Angela Bassett', 64461176.083333336),
#  ("Catherine O'Hara", 64352125.4),
#  ('Barbara Hershey', 64017407.75),
#  ('Meryl Streep', 62993187.5625),
#  ('Roberto Benigni', 62924923.4),
#  ('William Hurt', 62665463.0),
#  ('Chlo√´ Grace Moretz', 62402730.7),
#  ('Gary Busey', 62398479.5),
#  ('Keanu Reeves', 62374571.23076923),
#  ('Danny Glover', 62307504.375),
#  ('Isla Fisher', 62250965.666666664),
#  ('Marion Cotillard', 62166436.666666664),
#  ('Elizabeth Perkins', 62134203.5),
#  ('Will Ferrell', 61960679.5),
#  ('Harvey Keitel', 61470851.538461536),
#  ('Bill Pullman', 61207225.375),
#  ('Wesley Snipes', 61203345.666666664),
#  ('Winona Ryder', 60690711.09090909),
#  ('Paul Giamatti', 60510623.777777776),
#  ('Allison Janney', 60426855.166666664),
#  ('Ice Cube', 60334835.7),
#  ('Bette Midler', 60138259.777777776),
#  ('Frank McRae', 60031326.6),
#  ('Angela Lansbury', 59979368.833333336),
#  ('Aidan Quinn', 59705551.833333336),
#  ('Dustin Hoffman', 59622122.45454545),
#  ('Chi McBride', 59620370.2),
#  ('Kurt Russell', 58945833.692307696),
#  ('Ashley Judd', 58924490.55555555),
#  ('Rebel Wilson', 58766446.8),
#  ('January Jones', 58541131.0),
#  ('Bruce McGill', 58410246.0),
#  ('Jennifer Lopez', 58308538.63636363),
#  ('Josh Lucas', 58290847.571428575),
#  ('Martin Sheen', 58123603.833333336),
#  ('Colin Firth', 57860931.833333336),
#  ('Linda Hamilton', 57606550.6),
#  ('Stephen Rea', 57581297.0),
#  ('Salma Hayek', 57192449.333333336),
#  ('Kelly Preston', 57126359.166666664),
#  ('Kate Winslet', 57068127.333333336),
#  ('Carey Mulligan', 57026419.0),
#  ('Gene Wilder', 56782492.2),
#  ('J.K. Simmons', 56329059.55555555),
#  ('Ron Livingston', 56074553.428571425),
#  ('Jim Sturgess', 55997741.6),
#  ('John Hurt', 55590923.916666664),
#  ('Laurence Fishburne', 55489308.28571428),
#  ('F. Murray Abraham', 55473854.0),
#  ('Nick Nolte', 55083808.333333336),
#  ('Amy Ryan', 54964380.85714286),
#  ('Louis Gossett, Jr.', 54728949.4),
#  ('Justin Long', 54599458.5),
#  ('Matthew McConaughey', 54543349.777777776),
#  ('Miles Teller', 54445556.666666664),
#  ('Marcia Gay Harden', 54380521.666666664),
#  ('Bill Murray', 54231903.875),
#  ('Bill Hader', 54032397.2),
#  ('Irrfan Khan', 53888899.4),
#  ('Tim Curry', 53884566.777777776),
#  ('Charlton Heston', 53840021.375),
#  ('Robert De Niro', 53534555.678571425),
#  ('Clint Eastwood', 53521334.583333336),
#  ('Chris Pine', 52376337.5),
#  ('Helen Mirren', 52319896.777777776),
#  ('Stephen Lang', 52132205.6),
#  ('Bruce Greenwood', 52086190.71428572),
#  ('Javier Bardem', 52053731.833333336),
#  ('Eric Christian Olsen', 51996067.2),
#  ('Charles Grodin', 51502005.2),
#  ('Jason Isaacs', 51459660.4),
#  ('Mary Elizabeth Winstead', 51392338.4),
#  ('Aaron Taylor-Johnson', 51374808.0),
#  ('Clive Owen', 51193951.666666664),
#  ('Tim Matheson', 50851850.8),
#  ('Daniel Day-Lewis', 50559052.166666664),
#  ('Emile Hirsch', 50441437.375),
#  ('Forest Whitaker', 50300182.35714286),
#  ('Guy Pearce', 50232290.18181818),
#  ('Matthew Lillard', 50138824.333333336),
#  ('Dennis Quaid', 49874161.52941176),
#  ('Eugene Levy', 49561655.4),
#  ('Seth Green', 49517316.625),
#  ('Julianne Moore', 49479074.4375),
#  ('John Candy', 49386265.6),
#  ('Christopher Plummer', 49240370.06666667),
#  ('Peter Sarsgaard', 49018709.4),
#  ('Ned Beatty', 48967868.833333336),
#  ('Michael Ironside', 48557054.166666664),
#  ('Philip Seymour Hoffman', 47462785.0),
#  ('Michael Madsen', 47377651.28571428),
#  ('James Gandolfini', 47295645.0),
#  ('Sissy Spacek', 47240749.2),
#  ('Jennifer Jason Leigh', 47006902.375),
#  ('Robert Loggia', 46949303.2),
#  ('Thomas Jane', 46747568.833333336),
#  ('Daryl Hannah', 46717290.8),
#  ('Dan Hedaya', 46690397.0),
#  ('Jet Li', 46082173.428571425),
#  ('Maggie Gyllenhaal', 46026245.0),
#  ('Walter Matthau', 45957638.4),
#  ('Bruno Ganz', 45792875.4),
#  ('Felicity Jones', 45722752.125),
#  ('Dan Aykroyd', 45541398.54545455),
#  ('Tommy Lee Jones', 45368694.75),
#  ('Kristin Scott Thomas', 44871195.28571428),
#  ('Emily Watson', 44854140.166666664),
#  ('Dermot Mulroney', 44811365.571428575),
#  ('Brendan Fraser', 44725101.5),
#  ('Toni Collette', 44129415.8),
#  ('Dolph Lundgren', 44054431.0),
#  ('Steve Guttenberg', 43990678.6),
#  ('Rosario Dawson', 43808656.54545455),
#  ('Sam Rockwell', 43678269.0),
#  ('John Cleese', 43236471.0),
#  ('Hal Holbrook', 43072524.8),
#  ('George Kennedy', 43072028.0),
#  ('James Remar', 42856198.6),
#  ('Sean Penn', 42683704.28571428),
#  ('Susan Sarandon', 42615972.6),
#  ("Vincent D'Onofrio", 42474396.0),
#  ('Anna Paquin', 41996184.4),
#  ('Adam Scott', 41779200.44444445),
#  ('Madonna', 41336438.2),
#  ('Mark Strong', 41267788.55555555),
#  ('Cillian Murphy', 40586213.571428575),
#  ('Kathy Bates', 40379922.375),
#  ('Radha Mitchell', 40180060.28571428),
#  ('Joe Pantoliano', 40035086.0),
#  ('Ethan Hawke', 39972644.11764706),
#  ('Miranda Richardson', 39616209.71428572),
#  ('Alicia Vikander', 39606405.6),
#  ('Brian Dennehy', 38892955.0),
#  ('Joel Edgerton', 38579728.375),
#  ('Kiefer Sutherland', 38383505.45454545),
#  ('Matt Dillon', 38220725.0),
#  ('Ben Kingsley', 37818449.55555555),
#  ('Bill Nighy', 37388617.8),
#  ('Donnie Yen', 37297557.0),
#  ('John Cusack', 37001884.071428575),
#  ('Timothy Olyphant', 36600504.44444445),
#  ('Ellen Page', 36597250.571428575),
#  ('Ryan Phillippe', 36358498.8),
#  ('Mimi Rogers', 36281431.2),
#  ('Charlie Sheen', 36063943.0),
#  ('Donald Sutherland', 35799039.11111111),
#  ('John Krasinski', 35454339.0),
#  ('Jean-Claude Van Damme', 35365167.85714286),
#  ('Mickey Rourke', 35238585.1),
#  ('Peter Stormare', 35017273.2),
#  ('Phoebe Cates', 34987290.71428572),
#  ('Romany Malco', 34794941.166666664),
#  ('Gregory Hines', 34229899.428571425),
#  ('G√©rard Depardieu', 34157964.0),
#  ('Jonathan Rhys Meyers', 34105295.4),
#  ('Frank Langella', 34085643.833333336),
#  ('Rooney Mara', 34057628.6),
#  ('Deepika Padukone', 33671843.2),
#  ('Chevy Chase', 33569616.71428572),
#  ('Tilda Swinton', 33115330.85714286),
#  ('Ron Perlman', 32934411.0),
#  ('Derek Luke', 32274961.666666668),
#  ('Tom Selleck', 32188791.6),
#  ('Tim Robbins', 31881748.8),
#  ('Bubba Smith', 31663618.8),
#  ('David Graf', 31663618.8),
#  ('Michael Winslow', 31663618.8),
#  ('Eva Mendes', 31508644.444444444),
#  ('Dom DeLuise', 31290313.166666668),
#  ('Topher Grace', 31278953.0),
#  ('James Franco', 31117797.666666668),
#  ('Rachael Leigh Cook', 30863230.2),
#  ('John C. McGinley', 30358242.0),
#  ('Ellen Barkin', 30284019.2),
#  ('Juliette Binoche', 30087137.555555556),
#  ('Fred Ward', 30003895.333333332),
#  ('Konstantin Khabenskiy', 29092205.0),
#  ('Joseph Fiennes', 29036369.8),
#  ('Peter Ustinov', 28780587.8),
#  ('Ben Whishaw', 28536956.6),
#  ('Jeffrey Dean Morgan', 28087208.0),
#  ('Selma Blair', 27997227.8),
#  ("Michael O'Keefe", 27921550.0),
#  ('Bruce Dern', 27844205.42857143),
#  ('Emily Blunt', 27671906.166666668),
#  ('Peter Sellers', 27608945.833333332),
#  ('David Spade', 27498252.4),
#  ('Gwyneth Paltrow', 27103203.666666668),
#  ('Harry Dean Stanton', 26870843.333333332),
#  ('Albert Finney', 26746564.166666668),
#  ('Edward Herrmann', 26294454.8),
#  ('Paul Dano', 25701783.14285714),
#  ('Carrie Fisher', 25681651.166666668),
#  ('Jeremy Northam', 25479645.85714286),
#  ('Bridget Fonda', 25004683.2),
#  ('Melanie Griffith', 24987142.0),
#  ('Kate Hudson', 24640718.0),
#  ('Dominic West', 24479165.0),
#  ('Woody Allen', 23955997.444444444),
#  ('Martin Landau', 23910541.125),
#  ('Jim Belushi', 23734302.0),
#  ('Kim Basinger', 23686615.714285713),
#  ('Anthony Mackie', 23510257.6),
#  ('Kristy Swanson', 23371763.57142857),
#  ('Joseph Gordon-Levitt', 23350393.111111112),
#  ('Aishwarya Rai Bachchan', 23160607.6),
#  ('Jack Lemmon', 23119716.4),
#  ('Herbert Lom', 22142173.4),
#  ('Josh Hartnett', 22120935.0),
#  ('Jason Schwartzman', 21585990.5),
#  ('Lou Diamond Phillips', 21561737.5),
#  ('Burt Lancaster', 21018071.42857143),
#  ('C. Thomas Howell', 20995565.0),
#  ('Billy Bob Thornton', 20754282.4),
#  ('Lukas Haas', 20688412.6),
#  ('Robin Wright', 20445426.0),
#  ('Tom Sizemore', 19859850.166666668),
#  ("Beverly D'Angelo", 19735614.0),
#  ('Shah Rukh Khan', 19716026.5),
#  ('Dennis Haysbert', 19536424.833333332),
#  ('Evan Rachel Wood', 19206085.0),
#  ('David Niven', 18778489.333333332),
#  ('John Lithgow', 18762385.25),
#  ('Mia Farrow', 18230936.5),
#  ('Gabriel Byrne', 18201271.14285714),
#  ('Donald Pleasence', 18054256.0),
#  ('William Forsythe', 18044858.4),
#  ('Luke Wilson', 17988232.6),
#  ('Matthias Schoenaerts', 17421166.6),
#  ('Anjelica Huston', 17219687.0),
#  ('Julie Delpy', 17100128.85714286),
#  ('Kathleen Turner', 16405918.4),
#  ('Emma Roberts', 16324483.833333334),
#  ('David Thewlis', 16279827.833333334),
#  ('Bob Hoskins', 16158089.4),
#  ('Gael Garc√≠a Bernal', 16033571.8),
#  ('Patricia Clarkson', 15927332.2),
#  ('Geoffrey Lewis', 15924263.2),
#  ('Orson Welles', 15918542.8),
#  ('Robert Prosky', 15484708.833333334),
#  ('Barry Pepper', 14834049.285714285),
#  ('Tony Curtis', 14809120.833333334),
#  ('Mekhi Phifer', 14470545.4),
#  ('Randy Quaid', 14166195.2),
#  ('Jane Fonda', 13983440.0),
#  ('Akshay Kumar', 13693726.857142856),
#  ('Rutger Hauer', 13317008.666666666),
#  ('Judd Nelson', 12971658.0),
#  ('Adam Driver', 12860734.0),
#  ('Rosemarie DeWitt', 12737969.4),
#  ('Viola Davis', 12470192.833333334),
#  ('Gregory Peck', 12097807.666666666),
#  ('Chuck Norris', 11773705.333333334),
#  ('Dennis Hopper', 11488473.111111112),
#  ('Rupert Everett', 11216656.2),
#  ('Prakash Raj', 9805666.666666666),
#  ('Claire Forlani', 9756993.2),
#  ('Matthew Modine', 8657878.2),
#  ('Peter Falk', 8548497.42857143),
#  ('Rebecca De Mornay', 7983828.2),
#  ('Cary Grant', 7535000.0),
#  ('Vanessa Redgrave', 7461672.166666667),
#  ('Charles Bronson', 5994822.2),
#  ('John Wayne', 5547344.625),
#  ('Ajith Kumar', 3428571.4285714286),
#  ('Lionel Barrymore', 3378600.0),
#  ('Eric Stoltz', 1936699.3333333333)]

# %%
lead_actors_dict = {}
for element in train[['cast', 'revenue']].values:
    temp = min(1, len(literal_eval(element[0])))
    for i in range(temp):
        name = literal_eval(element[0])[i]['name']
        if name not in lead_actors_dict:
            lead_actors_dict[name] = [element[1], 1]
        else:
            lead_actors_dict[name][0] += element[1]
            lead_actors_dict[name][1] += 1
lead_actors_dict = {k: v for k, v in lead_actors_dict.items() if v[1] >= 5}
for actor in lead_actors_dict:
    lead_actors_dict[actor] = lead_actors_dict[actor][0] / lead_actors_dict[actor][1]

# %%
sorted(lead_actors_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Robert Downey Jr.', 531838522.8333333),
#  ('Shia LaBeouf', 489428383.5),
#  ('Elijah Wood', 440953864.4),
#  ('Vin Diesel', 362724163.0),
#  ('Hugh Jackman', 331559375.6),
#  ('Daniel Craig', 326010693.0),
#  ('Tom Cruise', 267587944.5),
#  ('Johnny Depp', 260574218.5),
#  ('Christian Bale', 233586861.8888889),
#  ('Harrison Ford', 228516060.0909091),
#  ('Julia Roberts', 204407270.0),
#  ('Tom Hanks', 199628364.33333334),
#  ('Jim Carrey', 196064719.1),
#  ('Brad Pitt', 192769702.5),
#  ('Pierce Brosnan', 190816996.8888889),
#  ('Adam Sandler', 180198717.1111111),
#  ('Bradley Cooper', 177532136.2),
#  ('Ben Stiller', 173917022.83333334),
#  ('Mark Wahlberg', 173337006.2142857),
#  ('Owen Wilson', 166883459.46153846),
#  ('Matt Damon', 162861065.0),
#  ('Sandra Bullock', 161314661.875),
#  ('Ewan McGregor', 159628369.8),
#  ('Naomi Watts', 156058484.0),
#  ('Milla Jovovich', 150000847.125),
#  ('Kevin Costner', 147564130.375),
#  ('Arnold Schwarzenegger', 145819196.58333334),
#  ('Michael J. Fox', 143034615.85714287),
#  ('Dwayne Johnson', 142858710.625),
#  ('Sylvester Stallone', 142748448.9375),
#  ('George Clooney', 128281925.71428572),
#  ('Michael Douglas', 127563316.0),
#  ('Russell Crowe', 126356119.25),
#  ('Robin Williams', 124399099.6),
#  ('Eddie Murphy', 120455735.9090909),
#  ('Patrick Swayze', 113700811.0),
#  ('Reese Witherspoon', 112572186.2),
#  ('Mel Gibson', 108864284.14285715),
#  ('Gerard Butler', 107370605.2),
#  ('Cameron Diaz', 105917417.16666667),
#  ('Hugh Grant', 104256424.8),
#  ('Sigourney Weaver', 103958500.8),
#  ('Nicolas Cage', 103739673.2),
#  ('Ben Affleck', 102616927.55555555),
#  ('Al Pacino', 101334022.71428572),
#  ('Sean Connery', 97607298.8),
#  ('Jamie Bell', 96882993.4),
#  ('John Travolta', 92561482.0),
#  ('Denzel Washington', 90408350.83333333),
#  ('Katherine Heigl', 89192549.0),
#  ('Roy Scheider', 87460430.5),
#  ('Meryl Streep', 87393125.0),
#  ('Tom Hardy', 85785923.8),
#  ('Antonio Banderas', 83479792.85714285),
#  ('Jake Gyllenhaal', 78615210.6),
#  ('Drew Barrymore', 77478348.66666667),
#  ('Dustin Hoffman', 72858663.4),
#  ('Steve Martin', 72195095.6),
#  ('Bill Murray', 70258828.5),
#  ('Marlon Brando', 69737852.2),
#  ('Dennis Quaid', 69174274.75),
#  ('Liam Neeson', 66817293.0),
#  ('Jeff Bridges', 66062740.14285714),
#  ('Jackie Chan', 64976348.5),
#  ('Tommy Lee Jones', 64411066.6),
#  ('Miles Teller', 64308856.4),
#  ('Burt Reynolds', 63463171.6),
#  ('Bruce Willis', 61374298.615384616),
#  ('Jessica Chastain', 59393314.8),
#  ('Charlton Heston', 58817207.571428575),
#  ('Matthew McConaughey', 56572791.6),
#  ('Samuel L. Jackson', 55811585.222222224),
#  ('Robert Redford', 55731173.5),
#  ('Ren√©e Zellweger', 54246218.4),
#  ('Keanu Reeves', 53021284.9),
#  ('Meg Ryan', 52387977.6),
#  ('Richard Gere', 51257148.875),
#  ('Morgan Freeman', 50188731.571428575),
#  ('Robert De Niro', 49354146.64285714),
#  ('Jason Bateman', 48858614.5),
#  ('Wesley Snipes', 48248844.0),
#  ('Clint Eastwood', 46102274.18181818),
#  ('Jet Li', 46082173.428571425),
#  ('Joaquin Phoenix', 45192060.0),
#  ('Steve Guttenberg', 43990678.6),
#  ('Gene Hackman', 43601703.71428572),
#  ('Jason Statham', 42969316.11111111),
#  ('Madonna', 41336438.2),
#  ('Sean Penn', 41219814.88888889),
#  ('Kurt Russell', 40237553.3),
#  ('Donnie Yen', 38677133.2),
#  ('Juliette Binoche', 38603544.0),
#  ('Chevy Chase', 37112111.0),
#  ('Danny DeVito', 35555166.6),
#  ('Jean-Claude Van Damme', 35365167.85714286),
#  ('Paul Newman', 34925274.0),
#  ('Matthew Broderick', 34504113.5),
#  ('Colin Farrell', 34259170.166666664),
#  ('Nicole Kidman', 34047107.71428572),
#  ('Cate Blanchett', 31393546.2),
#  ('John Cusack', 28567798.9),
#  ('Joseph Gordon-Levitt', 25975903.833333332),
#  ('Woody Allen', 25905390.14285714),
#  ('Shah Rukh Khan', 24908639.5),
#  ('Charlie Sheen', 24391831.0),
#  ('Burt Lancaster', 21018071.42857143),
#  ('Ethan Hawke', 17358067.375),
#  ('Kevin Bacon', 16390594.166666666),
#  ('Forest Whitaker', 16211685.0),
#  ('Mickey Rourke', 14470724.0),
#  ('Kirsten Dunst', 14119095.8),
#  ('Akshay Kumar', 13693726.857142856),
#  ('Gregory Peck', 12690969.2),
#  ('Chuck Norris', 11773705.333333334),
#  ('John Wayne', 6182142.857142857),
#  ('Ajith Kumar', 3428571.4285714286)]

# %%
train['cast'] = train['cast'].fillna('[]')
test['cast'] = test['cast'].fillna('[]')

train['top-cast-count'] = train['cast'].map(lambda x: inJson(x, actors_dict))
test['top-cast-count'] = test['cast'].map(lambda x: inJson(x, actors_dict))

train['lead-cast-count'] = train['cast'].map(lambda x: inJson(x, lead_actors_dict))
test['lead-cast-count'] = test['cast'].map(lambda x: inJson(x, lead_actors_dict))

# %%
train['crew'] = train['crew'].fillna('[]')
test['crew'] = test['crew'].fillna('[]')

train['crew-count'] = train['crew'].map(lambda x: len(literal_eval(x)))
test['crew-count'] = test['crew'].map(lambda x: len(literal_eval(x)))

# %%
plt.hist(np.log1p(train['crew-count']))
# Out:
# (array([ 16.,  64., 305., 352., 581., 732., 423., 261., 199.,  66.]),
#  array([0.        , 0.52729996, 1.05459991, 1.58189987, 2.10919982,
#         2.63649978, 3.16379974, 3.69109969, 4.21839965, 4.7456996 ,
#         5.27299956]),
#  <BarContainer object of 10 artists>)

# %%
train['log-crew-count'] = np.log1p(train['crew-count'])
test['log-crew-count'] = np.log1p(test['crew-count'])

# %%
def getDirectorNum(val):
    cnt = 0
    for x in literal_eval(val):
        if x['job'] == 'Director':
            cnt += 1
    return cnt
train['directors-count'] = train['crew'].map(getDirectorNum)
test['directors-count'] = test['crew'].map(getDirectorNum)

# %%
lead_directors_dict = {}
for val in train[['crew', 'revenue']].values:
    if val[0] == '[]':
        continue
    x = literal_eval(val[0])
    for i in range(len(x)):
        if x[i]['job'] == 'Director':
            name = x[i]['name']
            if name not in lead_directors_dict.keys():
                lead_directors_dict[name] = [val[1], 1]
            else:
                lead_directors_dict[name][0] += val[1]
                lead_directors_dict[name][1] += 1
            continue
lead_directors_dict = {i: v for i, v in lead_directors_dict.items() if v[1] >= 5}

for name in lead_directors_dict.keys():
    lead_directors_dict[name] = lead_directors_dict[name][0] / lead_directors_dict[name][1]

# %%
top_directors_dict = {}
for val in train[['crew', 'revenue']].values:
    v = literal_eval(val[0])
    for x in v:
        if x['job'] == 'Director':
            name = x['name']
            if name not in top_directors_dict.keys():
                top_directors_dict[name] = [val[1], 1]
            else:
                top_directors_dict[name][0] += val[1]
                top_directors_dict[name][1] += 1
top_directors_dict = {i: v for i, v in top_directors_dict.items() if v[1] >= 5}

for name in top_directors_dict.keys():
    top_directors_dict[name] = top_directors_dict[name][0] / top_directors_dict[name][1]

# %%
lead_directors = dict(sorted(lead_directors_dict.items(), key=lambda x: x[1], reverse=True)[:30])
top_directors = dict(sorted(top_directors_dict.items(), key=lambda x: x[1], reverse=True))

# %%
def countDirector(val, dic):
    cnt = 0
    for x in literal_eval(val):
        if x['job'] == 'Director' and x['name'] in dic:
            cnt += 1
    return cnt
def checkDirector(val, dic):
    for x in literal_eval(val):
        if x['job'] == 'Director' and x['name'] in dic:
            return 1
    return 0

train['top-directors-count'] = train['crew'].map(lambda x: countDirector(x, top_directors))
train['has-lead-director'] = train['crew'].map(lambda x: checkDirector(x, lead_directors))
test['top-directors-count'] = test['crew'].map(lambda x: countDirector(x, top_directors))
test['has-lead-director'] = test['crew'].map(lambda x: checkDirector(x, lead_directors))

# %%
train['budget-year-ratio'] = train.apply(lambda x: x['budget'] / x['year'], axis=1)
test['budget-year-ratio'] = test.apply(lambda x: x['budget'] / x['year'], axis=1)
train['budget-cast-ratio'] = train.apply(lambda x: x['budget'] / x['cast-count'] if x['cast-count'] != 0 else 0, axis=1)
test['budget-cast-ratio'] = test.apply(lambda x: x['budget'] / x['cast-count'] if x['cast-count'] != 0 else 0, axis=1)
train['budget-topcast-ratio'] = train.apply(lambda x: x['budget'] / x['top-cast-count'] if x['top-cast-count'] != 0 else 0, axis=1)
test['budget-topcast-ratio'] = test.apply(lambda x: x['budget'] / x['top-cast-count'] if x['top-cast-count'] != 0 else 0, axis=1)
train['budget-leadcast-ratio'] = train.apply(lambda x: x['budget'] / x['lead-cast-count'] if x['lead-cast-count'] != 0 else 0, axis=1)
test['budget-leadcast-ratio'] = test.apply(lambda x: x['budget'] / x['lead-cast-count'] if x['lead-cast-count'] != 0 else 0, axis=1)

# %%
feature_names = ['log-budget', 'has-collection', 'log-popularity', 
                 'runtime', 'genres-count', 'genres-rank', 'has-homepage', 'originally-english', 
                 'overview-length', 'companies-count', 'companies-rank', 'top-companies-count', 
                'countries-count', 'usa-produced', 'year', 'month', 'day', 
                'dayofweek', 'weekofyear', 'quarter', 'spoken-languages-count', 'spoken-english', 
                'has-tagline', 'title-length', 'has-keywords', 'log-cast-count', 'top-cast-count', 
                'lead-cast-count', 'crew-count', 'log-crew-count', 'directors-count', 
                'top-directors-count', 'has-lead-director', 'budget-year-ratio', 'budget-cast-ratio',
                'budget-topcast-ratio', 'budget-leadcast-ratio']

# %%
train_x = train[feature_names]
train_y = train['log-revenue']
test_x = test[feature_names]

# %%
train_x.to_csv('train_x.csv', index=False)
train_y.to_csv('train_y.csv', index=False)
test_x.to_csv('test_x.csv', index=False)

# %%
train_x = pd.read_csv('train_x.csv')
train_y = pd.read_csv('train_y.csv')
test_x = pd.read_csv('test_x.csv')

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(train_x, train_y.values, test_size=0.1, random_state=42)

# %%
from nni.algorithms.feature_engineering.gradient_selector import FeatureGradientSelector
from nni.algorithms.feature_engineering.gbdt_selector import GBDTSelector
selector = FeatureGradientSelector(n_features=16, classification=False)
selector.fit(X_train, y_train)
final_features = selector.get_selected_features()
print(final_features)
# Out:
# [ 0  1  2  3  4  7 10 21 22 23 25 28 29 30 33 34]

# %%
X_train = X_train.iloc[:, final_features]
X_valid = X_valid.iloc[:, final_features]
X_test = test_x.iloc[:, final_features]

# %%
# from sklearn.neighbors import KNeighborsRegressor
# regressor = KNeighborsRegressor()

from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor, RandomForestRegressor
regressor = GradientBoostingRegressor(n_estimators=100, random_state=42)
regressor.fit(X_train, y_train)
from sklearn.metrics import mean_squared_error
y_pred = regressor.predict(X_valid)
mse = mean_squared_error(y_valid, y_pred)
mse
# Out:
# 3.2942678957225935

# %%
pred = regressor.predict(X_test)
pred = np.expm1(pred).astype(int)
df = pd.DataFrame(pred.T, columns=['revenue'])
df.insert(0, 'id', test['id'])
df
df.to_csv('submission0305.csv', index=False)

# %%
stop here

# %%
regressor = RandomForestRegressor(random_state=42)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_valid)
mse = mean_squared_error(y_valid, y_pred)
mse

# %%
pred = regressor.predict(test_x)
pred = np.expm1(pred).astype(int)
df = pd.DataFrame(pred.T, columns=['revenue'])
df.insert(0, 'id', test['id'])
df
df.to_csv('submission0305_2.csv', index=False)
